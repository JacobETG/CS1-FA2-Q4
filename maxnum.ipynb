# %% [markdown]
# <a href="https://colab.research.google.com/github/JacobETG/cs1-python-pearl-guadalquiver-FA1-and-FA2-/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ask user to input 3 numbers
num_1 = int(input("first number"))
num_2 = int(input("second number"))
num_3 = int(input("third number"))


# compare the numbers
if num_1 > num_2 and num_1 > num_3:
    print(f"first number is the largest.")
elif num_2 > num_1 and num_2 > num_3:
    print(f"second number is the largest.")
else:
    print(f"third number is the largest.")
# Out:
# first number12
# second number17
# third number13
# second number is the largest.
