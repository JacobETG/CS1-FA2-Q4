# %% [markdown]
# <a href="https://colab.research.google.com/github/JacobETG/CS1-FA2-Q4/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input ("name")
num1 = int(input("first number"))
num2 = int(input("second number"))
num3 = int(input("third number"))

print("Hello, name!")

#compare the numbers

if num1 > num2 and num1 > num3:
  print(f"first number is the largest.")
elif num2 > num1 and num2 > num3:
  print(f"second number is the largest.")
else:
  print(f"third number is the largest.")
# Out:
# name Jacob
# first number 12
# second number 9
# third number 8
# Hello, name!
# first number is the largest.
